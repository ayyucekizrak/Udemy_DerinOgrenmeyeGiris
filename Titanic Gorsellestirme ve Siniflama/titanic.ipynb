# %% [markdown]
# # TITANIC İkili Veri Sınıflandırma
#
# ---
#
#
# [<img align="right" width="100" height="100" src="http://www.i2symbol.com/images/symbols/style-letters/circled_latin_capital_letter_a_u24B6_icon_128x128.png">](https://www.ayyucekizrak.com/)

# %% [markdown]
# **Colab** için kimlik doğrulama admlarını gerçekleştirme...

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os
os.chdir("/content/drive/My Drive/Udemy_DerinOgrenmeyeGiris/Titanic Gorsellestirme ve Siniflama")
# !pwd
# Out:
# /content/drive/My Drive/Udemy_DerinOgrenmeyeGiris/Titanic Gorsellestirme ve Siniflama

# %% [markdown]
# **Kütüphaneden gereken paketlerin yüklenmesi..**.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import re

from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **Ön İşlemler**

# %%
# ÖN İŞLEMLER

def preprocess(data):
    
    #Kabin
    data.Cabin.fillna('0', inplace=True)
    data.loc[data.Cabin.str[0] == 'A', 'Cabin'] = 1
    data.loc[data.Cabin.str[0] == 'B', 'Cabin'] = 2
    data.loc[data.Cabin.str[0] == 'C', 'Cabin'] = 3
    data.loc[data.Cabin.str[0] == 'D', 'Cabin'] = 4
    data.loc[data.Cabin.str[0] == 'E', 'Cabin'] = 5
    data.loc[data.Cabin.str[0] == 'F', 'Cabin'] = 6
    data.loc[data.Cabin.str[0] == 'G', 'Cabin'] = 7
    data.loc[data.Cabin.str[0] == 'T', 'Cabin'] = 8
    
    # Cinsiyeti tam sayıya çevirelim
    data['Sex'].replace('female', 1, inplace=True)
    data['Sex'].replace('male', 2, inplace=True)
    
    # Gemiye biniş limanlarını tam sayıya çevirelim
    data['Embarked'].replace('S', 1, inplace=True)
    data['Embarked'].replace('C', 2, inplace=True)
    data['Embarked'].replace('Q', 3, inplace=True)
    
    # Olmayan (NA) yaş değerlerini medyan ile dolduralım
    data['Age'].fillna(data['Age'].median(), inplace=True)
    data['Fare'].fillna(data['Fare'].median(), inplace=True)
    data['Embarked'].fillna(data['Embarked'].median(), inplace=True)
    
    # İstersek olmayan (NA) değerleri tamamen silebiliriz
    # data.dropna(subset=['Fare', 'Embarked'], inplace=True, how='any')
    return data

def group_titles(data):
    data['Names'] = data['Name'].map(lambda x: len(re.split(' ', x)))
    data['Title'] = data['Name'].map(lambda x: re.search(', (.+?) ', x).group(1))
    data['Title'].replace('Master.', 0, inplace=True)
    data['Title'].replace('Mr.', 1, inplace=True)
    data['Title'].replace(['Ms.','Mlle.', 'Miss.'], 2, inplace=True)
    data['Title'].replace(['Mme.', 'Mrs.'], 3, inplace=True)
    data['Title'].replace(['Dona.', 'Lady.', 'the Countess.', 'Capt.', 'Col.', 'Don.', 'Dr.', 'Major.', 'Rev.', 'Sir.', 'Jonkheer.', 'the'], 4, inplace=True)

def data_subset(data):
    features = ['Pclass', 'SibSp', 'Parch', 'Sex', 'Names', 'Title', 'Age', 'Cabin'] #, 'Fare', 'Embarked']
    lengh_features = len(features)
    subset = data[features]#.fillna(0)
    return subset, lengh_features

def create_model(train_set_size, input_length, num_epochs, batch_size):
    model = Sequential()
    model.add(Dense(7, input_dim=input_length, activation='softplus'))
    model.add(Dense(3, activation='softplus'))
    model.add(Dense(1, activation='softplus'))

    lr = .001
    adam0 = Adam(lr = lr)

    # Modeli derleyip ve daha iyi bir sonuç elde edildiğinde ağırlıkları kaydedelim
    model.compile(loss='binary_crossentropy', optimizer=adam0, metrics=['accuracy'])
    filepath = 'weights.best.hdf5'
    checkpoint = ModelCheckpoint(filepath, monitor='acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]

    history_model = model.fit(X_train[:train_set_size], Y_train[:train_set_size], callbacks=callbacks_list, epochs=num_epochs, batch_size=batch_size, verbose=0) #40, 32
    return model, history_model

def plots(history):
    loss_history = history.history['loss']
    acc_history = history.history['acc']
    epochs = [(i + 1) for i in range(num_epochs)]

    ax = plt.subplot(211)
    ax.plot(epochs, loss_history, color='red')
    ax.set_xlabel('Epochs')
    ax.set_ylabel('Error Rate\n')
    ax.set_title('Error Rate per Epoch\n')

    ax2 = plt.subplot(212)
    ax2.plot(epochs, acc_history, color='blue')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Accuracy\n')
    ax2.set_title('Accuracy per Epoch\n')

    plt.subplots_adjust(hspace=0.8)
    plt.savefig('Accuracy_loss.png')
    plt.close()

def test(batch_size):
    test = pd.read_csv('test.csv', header=0)
    test_ids = test['PassengerId']
    test = preprocess(test)
    group_titles(test)
    testdata, _ = data_subset(test)

    X_test = np.array(testdata).astype(float)

    output = model.predict(X_test, batch_size=batch_size, verbose=0)
    output = output.reshape((418,))

    # Sonuçları ondalık sayı yerine 0-1 olarak değiştirebilirsiniz
    #outputBin = np.zeros(0)
    #for element in output:
    #    if element <= .5:
    #         outputBin = np.append(outputBin, 0)
    #    else:
    #        outputBin = np.append(outputBin, 1)
    #output = np.array(outputBin).astype(int)

    column_1 = np.concatenate((['PassengerId'], test_ids ), axis=0 )
    column_2 = np.concatenate( ( ['Survived'], output ), axis=0 )

    f = open("output.csv", "w")
    writer = csv.writer(f)
    for i in range(len(column_1)):
        writer.writerow( [column_1[i]] + [column_2[i]])
    f.close()

# %% [markdown]
# ### Eğitim ve Test İşlemleri - Sonuçların Grafikleştirilmesi

# %%
# sonuçların yeniden üretilebilir olması için
seed = 7
np.random.seed(seed)


train = pd.read_csv('train.csv', header=0)


preprocess(train)
group_titles(train)


num_epochs = 100
batch_size = 32



traindata, lengh_features = data_subset(train)

Y_train = np.array(train['Survived']).astype(int)
X_train = np.array(traindata).astype(float)


train_set_size = int(.67 * len(X_train))


model, history_model = create_model(train_set_size, lengh_features, num_epochs, batch_size)

plots(history_model)


X_validation = X_train[train_set_size:]
Y_validation = Y_train[train_set_size:]


loss_and_metrics = model.evaluate(X_validation, Y_validation, batch_size=batch_size)
print ("loss_and_metrics")

test(batch_size)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#
# Epoch 00001: acc improved from -inf to 0.57215, saving model to weights.best.hdf5
#
# Epoch 00002: acc did not improve from 0.57215
#
# Epoch 00003: acc did not improve from 0.57215
#
# Epoch 00004: acc did not improve from 0.57215
#
# Epoch 00005: acc did not improve from 0.57215
#
# Epoch 00006: acc improved from 0.57215 to 0.60570, saving model to weights.best.hdf5
#
# Epoch 00007: acc did not improve from 0.60570
#
# Epoch 00008: acc improved from 0.60570 to 0.60906, saving model to weights.best.hdf5
#
# Epoch 00009: acc improved from 0.60906 to 0.61409, saving model to weights.best.hdf5
#
# Epoch 00010: acc improved from 0.61409 to 0.61577, saving model to weights.best.hdf5
#
# Epoch 00011: acc improved from 0.61577 to 0.61745, saving model to weights.best.hdf5
#
# Epoch 00012: acc improved from 0.61745 to 0.62584, saving model to weights.best.hdf5
#
# Epoch 00013: acc improved from 0.62584 to 0.62919, saving model to weights.best.hdf5
#
# Epoch 00014: acc improved from 0.62919 to 0.63926, saving model to weights.best.hdf5
#
# Epoch 00015: acc did not improve from 0.63926
#
# Epoch 00016: acc improved from 0.63926 to 0.64094, saving model to weights.best.hdf5
#
# Epoch 00017: acc improved from 0.64094 to 0.68121, saving model to weights.best.hdf5
#
# Epoch 00018: acc improved from 0.68121 to 0.68456, saving model to weights.best.hdf5
#
# Epoch 00019: acc improved from 0.68456 to 0.70638, saving model to weights.best.hdf5
#
# Epoch 00020: acc improved from 0.70638 to 0.74161, saving model to weights.best.hdf5
#
# Epoch 00021: acc did not improve from 0.74161
#
# Epoch 00022: acc improved from 0.74161 to 0.75503, saving model to weights.best.hdf5
#
# Epoch 00023: acc did not improve from 0.75503
#
# Epoch 00024: acc did not improve from 0.75503
#
# Epoch 00025: acc improved from 0.75503 to 0.75503, saving model to weights.best.hdf5
#
# Epoch 00026: acc improved from 0.75503 to 0.75503, saving model to weights.best.hdf5
#
# Epoch 00027: acc did not improve from 0.75503
#
# Epoch 00028: acc improved from 0.75503 to 0.75671, saving model to weights.best.hdf5
#
# Epoch 00029: acc improved from 0.75671 to 0.77181, saving model to weights.best.hdf5
#
# Epoch 00030: acc did not improve from 0.77181
#
# Epoch 00031: acc did not improve from 0.77181
#
# Epoch 00032: acc did not improve from 0.77181
#
# Epoch 00033: acc improved from 0.77181 to 0.77517, saving model to weights.best.hdf5
#
# Epoch 00034: acc did not improve from 0.77517
#
# Epoch 00035: acc improved from 0.77517 to 0.77685, saving model to weights.best.hdf5
#
# Epoch 00036: acc improved from 0.77685 to 0.77852, saving model to weights.best.hdf5
#
# Epoch 00037: acc did not improve from 0.77852
#
# Epoch 00038: acc did not improve from 0.77852
#
# Epoch 00039: acc improved from 0.77852 to 0.78188, saving model to weights.best.hdf5
#
# Epoch 00040: acc did not improve from 0.78188
#
# Epoch 00041: acc did not improve from 0.78188
#
# Epoch 00042: acc did not improve from 0.78188
#
# Epoch 00043: acc did not improve from 0.78188
#
# Epoch 00044: acc improved from 0.78188 to 0.78523, saving model to weights.best.hdf5
#
# Epoch 00045: acc improved from 0.78523 to 0.78691, saving model to weights.best.hdf5
#
# Epoch 00046: acc did not improve from 0.78691
#
# Epoch 00047: acc improved from 0.78691 to 0.79027, saving model to weights.best.hdf5
#
# Epoch 00048: acc did not improve from 0.79027
#
# Epoch 00049: acc did not improve from 0.79027
#
# Epoch 00050: acc did not improve from 0.79027
#
# Epoch 00051: acc did not improve from 0.79027
#
# Epoch 00052: acc improved from 0.79027 to 0.79027, saving model to weights.best.hdf5
#
# Epoch 00053: acc did not improve from 0.79027
#
# Epoch 00054: acc did not improve from 0.79027
#
# Epoch 00055: acc improved from 0.79027 to 0.79027, saving model to weights.best.hdf5
#
# Epoch 00056: acc improved from 0.79027 to 0.79698, saving model to weights.best.hdf5
#
# Epoch 00057: acc did not improve from 0.79698
#
# Epoch 00058: acc did not improve from 0.79698
#
# Epoch 00059: acc did not improve from 0.79698
#
# Epoch 00060: acc improved from 0.79698 to 0.79866, saving model to weights.best.hdf5
#
# Epoch 00061: acc improved from 0.79866 to 0.79866, saving model to weights.best.hdf5
#
# Epoch 00062: acc improved from 0.79866 to 0.80537, saving model to weights.best.hdf5
#
# Epoch 00063: acc did not improve from 0.80537
#
# Epoch 00064: acc did not improve from 0.80537
#
# Epoch 00065: acc did not improve from 0.80537
#
# Epoch 00066: acc did not improve from 0.80537
#
# Epoch 00067: acc did not improve from 0.80537
#
# Epoch 00068: acc did not improve from 0.80537
#
# Epoch 00069: acc did not improve from 0.80537
#
# Epoch 00070: acc did not improve from 0.80537
#
# Epoch 00071: acc did not improve from 0.80537
#
# Epoch 00072: acc did not improve from 0.80537
#
# Epoch 00073: acc did not improve from 0.80537
#
# Epoch 00074: acc did not improve from 0.80537
#
# Epoch 00075: acc improved from 0.80537 to 0.80537, saving model to weights.best.hdf5
#
# Epoch 00076: acc did not improve from 0.80537
#
# Epoch 00077: acc did not improve from 0.80537
#
# Epoch 00078: acc did not improve from 0.80537
#
# Epoch 00079: acc improved from 0.80537 to 0.80705, saving model to weights.best.hdf5
#
# Epoch 00080: acc did not improve from 0.80705
#
# Epoch 00081: acc did not improve from 0.80705
#
# Epoch 00082: acc did not improve from 0.80705
#
# Epoch 00083: acc did not improve from 0.80705
#
# Epoch 00084: acc did not improve from 0.80705
#
# Epoch 00085: acc did not improve from 0.80705
#
# Epoch 00086: acc improved from 0.80705 to 0.80872, saving model to weights.best.hdf5
#
# Epoch 00087: acc did not improve from 0.80872
#
# Epoch 00088: acc did not improve from 0.80872
#
# Epoch 00089: acc did not improve from 0.80872
#
# Epoch 00090: acc improved from 0.80872 to 0.80872, saving model to weights.best.hdf5
#
# Epoch 00091: acc did not improve from 0.80872
#
# Epoch 00092: acc improved from 0.80872 to 0.81208, saving model to weights.best.hdf5
#
# Epoch 00093: acc did not improve from 0.81208
#
# Epoch 00094: acc did not improve from 0.81208
#
# Epoch 00095: acc improved from 0.81208 to 0.81376, saving model to weights.best.hdf5
#
# Epoch 00096: acc did not improve from 0.81376
#
# Epoch 00097: acc did not improve from 0.81376
#
# Epoch 00098: acc did not improve from 0.81376
#
# Epoch 00099: acc improved from 0.81376 to 0.81376, saving model to weights.best.hdf5
#
# Epoch 00100: acc did not improve from 0.81376
# 295/295 [==============================] - 0s 214us/step
# loss_and_metrics
